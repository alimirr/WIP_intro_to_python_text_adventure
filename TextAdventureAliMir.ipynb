# %%
"""
@author: Ali.Mir
"""


"""
    DocString:
    
    A) Introduction:
        
    This game is based mostly on my imagination, using characters from real 
    world fiction. It consists of 3 stages and an introduction. It includes
    the functions failure and success. This game requires knowledge of various
    pop culture and movie/TV references to win in the first run. It also
    requires knowing the references to actualy enjoy the game and understand
    the humour. 
    
    Round 1: Decide Who the best Spider-Man is.
    Round 2: Either have a Pokemon battle or face Spongebob.
    Round 3: Defeat the Architect.
    
    B) Known Bugs and/or Errors:
    None.
    
"""

import time
from IPython.display import Image #importing to embed images
import random 
import sys #importing for game exit()



def slowPrint(string, textSpeed = 0.07): #Slowing down text to make it readable on the go
    for letter in string:
        print(letter, end='')
        time.sleep(textSpeed)
        
######################    Introdution    ##################################

def introduction():
    """
    DocString:
    
    
"""
    slowPrint(f"""
Architect:    
Long ago, in a distan- 
Man! That is such a terrible way to tell a story.
Not gonna lie though, Samurai Jack was pretty dope. Anyway, young coder,
you're in for a treat! What are you in for you ask? Well, imagine a land
without copyright issues or fourth walls. The look on your face 
suggests, either you're confused \U0001F923 or constipated or are here to 
break my code \U0001F620

Well, in that case, forget everything I said.

You have been cursed by the evil lord Chase'ura to be forever banished
in this realm of pop culture and everything, I the architect, cares for.

I am sure you have a lot of questions but-    
    """
    )
    display(Image(filename='wedontdothathere.jpg')) 
    
    slowPrint(f"""
{'-'*40}
So, oh naive one, do you remember your name?

    """)
    global player_name #initialising global static variable
    player_name = input(prompt = "I mean, yeah, I guess. I am ")
    player_name = player_name.capitalize()
    slowPrint("""
That is correct, """ + player_name + """. I'm glad your brain is still intact.
So, I have good news and bad news. The good news is, I am about to have a lot of 
fun. The bad news is, the only way out of here and to break the curse of Chase'ura
you need to prove that you're worthy of the Throne of Dankness. 
    """)
    input("""
    
    Press Enter to reveal the Throne of Dankness.
    
    """)
    display(Image(filename='Throne.jpg')) 

    slowPrint(f"""
The throne will give you the power to break the curse and return 
you to your home. Disclaimer: Keep toilet humour to a minimum. 

{'*'*40}
   LET THE TRIALS OF THE DANK BEGIN!
{'*'*40}

Oh and also, don't die. 
    """)
    trial1()
    
    
##################  Trial1() is stage 1 called in the introduction  #########################


def trial1():
    
    slowPrint(f"""
{'*'*len("Trial 1 has commenced.")}
Trial 1 has commenced.
{'*'*len("Trial 1 has commenced.")}
    """)
    input("""
    
    Press Enter when you're ready.
    
    """)
    
    slowPrint(f"""
Hi {player_name}, I am Rya- I mean *clears throat* Deadpool. Wow, you look worse
than my beautiful face. You can't tell how bad my face is because of this mask, but
trust me, it's bad. And I mean realllyyy bad. 
""")
    display(Image(filename='Deadpool.jpeg'))
    input("""
    
    Press Enter to continue.
    
    """)
    slowPrint(f"""
Have you been working tirelessly trying to understand when to indent and when 
not to, as well? Yeah, it's a Motherf- HEYYY! Don't pretend this is an R rated
program. Let's get on with the trial before Chase'ura deducts marks for insinuated profanity. 
{'-'*40}
I will keep this easy. One question. Three choices. Infinite possibilities. Haha,
just kidding. Each choice represents a path to the next trials. Each more 
treacherous than the other. It's a sticky decision *snickers* You'll get the
joke later...
{'-'*40}
""")
    input("""
    
    Press Enter to continue.
    
    """)
    slowPrint(f"""
Who was the best Spider-Man? Type the correct letter (A or B or C).
{'-'*40}
A. Toby Maguire
B. Andrew Garfield
C. Tom Holland
{'-'*40}

    """)

   #introducing dummy for loop for eception handling of incorrect entries

    for x in range(4):
        choiceTrial1 = input(prompt = "Choose wisely: ")
        if choiceTrial1.lower() == 'a':
            
            Trail2A()
        elif choiceTrial1.lower() == 'b':
            slowPrint("""
            
The Architect appears and interrupts the trial.
The Architect: You are an abomination with no taste. 
*Lasers you*

            """)
            Failure()
        elif choiceTrial1.lower() == 'c':
            slowPrint("Trial 2C")
            trail2C()
            
            
            
        else:
            if x == 0:
                slowPrint("incorrect option. dont test my patience.")
            elif x == 1:
                slowPrint("incorrect option again. I'm warning you")
            elif x == 2:
                slowPrint("Try again. Choose your keys carefully. Do you think you can you regenerate? Asking for a friend.")
            elif x == 3:
                slowPrint("DEAD")
            else:
                slowPrint("Congrats. You broke my code. I will now go cry in the corner.")
######################    Trial2A    ##################################                
def Trail2A():
    slowPrint(f"""
    
{'*'*len("Successfully completed the first trial.")}
Successfully completed the first trial.
{'*'*len("Successfully completed the first trial.")}

    """)
    input("""
    
Press Enter to continue.
    
    """)
    slowPrint("""
    
A big yellow sponge with an annoying laugh has appeared.

    """)
    display(Image(filename='Spongebob.gif'))
    slowPrint("""

Spongebob: A fan of Toby huh. This trail may be easier than the other two,
but if, and only if, you are a friend of Patrick. Only the chosen ones will know
his highness and proceed to trail 3.

Riddle me this:

What is funnier than 24?

Your options are:

A. Because 7 8 9
B. Because 7 ate 9
C. 25
    """)
    for SpongeChoice in range(3):
        option = (input(prompt = "Choose your option.")).lower()
        if option == 'a' or option == "because 7 8 9":
            slowPrint(f""""
Spongebob: What??? I don't get it. INTO THE JELLYFISH PIT YOU GO.
            """)
            Failure()
        elif option == 'b' or option == "because 7 ate 9":
            slowPrint("""
Spongebob: HAHAHAHAHAHAHAHAHAHAHAHA *wipes tear* I get it. But no. The Krusty
Krab now owns you. 
            """)
            Failure()
        elif option == 'c' or option == "25":
            slowPrint("""
Spongebob: HAHAHAHAHAHAHAHAHAHAHAHA *wipes tear* hey, you wanna know what's 
funnier than 25? *holds laugh*

Spongebob breaks into an uncontrollable fit of laughter. You are free to proceed.
            """)
            Trail3() #calling 3rd stage of the game
        else:
            if SpongeChoice == 0 or SpongeChoice == 1:
                slowPrint("""
Wrong. Try again. Hurry, I need to feed Gary.
                """)
            elif SpongeChoice == 2:
                slowPrint("""
                
Spongebob got bored and left the trial. You are now stranded with nothing left 
to do.
                """)
                Failure()
                
######################    Trial2C    ##################################

def trail2C():# second variant of stage 2. Also called in stage 1
    
#THIS STAGE IS A POKEMON BATTLE. Auto options selections are enabled if you keep entering bogus statements
    
    slowPrint(f"""
    
{'*'*len("Successfully completed the first trial.")}
Successfully completed the first trial.
{'*'*len("Successfully completed the first trial.")}

    """)
    input("""

Press Enter to continue.

        """)
    
    #intro of challenger
    slowPrint(f"""
    
You see a massive orange dragon breathing fire. There is an impubescent child
next to him. 
Impubescent child: Hey {player_name}! I am Ash Ketchum from Pallet Town and
I challenge you to a duel! My Charizard is unbeaten, and I plan to keep it that
way. You have the choice of 2 Pokemon.

""")
    display(Image(filename='AshCharizard.gif'))
    input("""
    
Press Enter to continue.
    
    """)
    #Intro of your pokemon
    slowPrint(f"""
First is Blastoise, a water type Pokemon, with massive water canons coming out
of its shell. 
    """)
    display(Image(filename='Blastoise.png'))
    input("""
    
Press Enter to see your next Pokemon.
    
    """)
    slowPrint(f"""
Second is Venasaur, a grass type Pokemon, with a madly powerful Solar Beam
attack.
    """)
    display(Image(filename='Venasaur.png'))
    
    slowPrint(f"""
So, {player_name}, who will it be?



Enter 'A' for Blastoise or 'B' for Venasaur.

    """)
    for Choice in range(3):#Dummy for loop for bogus entries and default answer
        pokemon = (input(prompt = "Type your choice and press enter:  ")).lower()
        if pokemon == 'a' or pokemon == 'blastoise':
            Blastoise()
        
        elif pokemon == 'b' or pokemon == 'venasaur':
            Venasaur()
        else:
            if Choice == 0 or Choice == 1:
                slowPrint("incorrect entry. Try again")
            elif Choice == 2:
                slowPrint("You struggle with direction. Choosing randomly.")
                randompokemon = random.randint(0,1)
                if randompokemon == 0:
                    slowPrint("Choosing Blastoise")
                    Blastoise()
                elif randompokemon == 1:
                    slowPrint("Choosing Venasaur")
                    Venasaur()
                    
def Blastoise():#function called in trial 2C is Blastoise is chosen
    slowPrint(f"""
    
You chose Blastoise. A wise choice because water is strong against fire.

Choose your attack:
Enter 'A' for Hydropump.
or 
Enter 'B' for Skullbash.

            """)
    for attackChoice in range(3):
        attack = (input(prompt = "Type your choice and press enter:  ")).lower()
        if attack == 'a' or attack == 'hydropump':
            slowPrint(f"""
The attack was super effective. You One shot Charizard. You won. Proceed to the 
final trial.
""")
            Trail3()#calling the final trial
        elif attack == 'b' or attack == 'Skullbash':
            slowPrint(f"""
            
The attack did considerable damage but Charizard survived. Charizard took 
Blastoise in a hold and shot up in the sky. IT IS A SEISMIC TOSS. Blastoise hits the 
ground with unimaginable force and can no longer continue to fight. 

""")
            Failure()
        else:
            if attackChoice == 1 or attackChoice == 0:
                slowPrint("\n\nIncorrect entry. Try again. Charizard will not wait.\n")
            elif attackChoice == 2:
                slowPrint(f"""
                
Charizard got bored and slapped Blastoise with his tail. Blastoise is humiliated
and refuses to fight on. 

""")
                Failure()
            else:
                print("Program failed successfully. The architect is sad")
                exit() 
def Venasaur():#Just like the Blastoise function, this is called in trial 2C when Venasaur is chosen
    slowPrint(f"""
    
You chose Venasaur. A poor choice because leaf type is weak against fire.

Choose your attack:
Enter 'A' for Hyper Beam.
or 
Enter 'B' for Razor Leaf.

            """)
    for attackChoice in range(3):# Dummy loop to handle bogus entries
        attack =(input(prompt = "\nType your choice and press enter:  ")).lower()
        if attack == 'a' or attack == 'hyper beam':
            slowPrint(f"""
            
The attack was effective. You One shot Charizard. You won. Proceed to the 
final trial.

""")
            Trail3()
        elif attack == 'b' or attack == 'razor leaf':
            slowPrint(f"""
            
The attack was ineffective. Charizard used Fireblast. Venasaur is a roasted
vegetable. 

""")
            input("""
    
Press Enter to continue.
    
    """)
            Failure()
        else:
            if attackChoice == 1 or attackChoice ==0:
                slowPrint("Incorrect entry. Try again. Charizard will not wait.\n")
            elif attackChoice == 2:
                slowPrint(f"""
                
Charizard got bored and called Venasaur a vegetable. Venasaur is crying
and refuses to fight on. 

""")
                input("""
    
Press Enter to continue.
    
    """)
                Failure()
            else:
                print("Program failed successfully. The architect is sad")
                exit()
    
######################    Trial3    ##################################

def Trail3():#Defining the third trial
    
    slowPrint(f"""
    
{'*'*len("Successfully completed the second trial.")}
Successfully completed the second trial.
{'*'*len("Successfully completed the second trial.")}

    """)
    input("""
    
Press Enter to continue.
    
    """)
    
    transition()#just a function that prints a transition into the stage
    
    slowPrint(f"""
A flying car lands in front of you. Two teenagers are inside
Ron: What are you waiting for? Get in already!

You get in.

Hermoine: I'm Hermoine and this is Ron. These trials are a scam. Win or lose,
You will forever be stuck. It's a big loop and the whole thing starts over
if you win. We call this place the Matrix. And to break the Matrix we need to 
get to the Oracle. You don't know this but you are the chosen one and it is 
only you who can overpower the magic of the Architect. 

{player_name}: Me? The chosen one? 

Ron: We don't have time to explain. If the Architect finds out, he will send 
the agents to subjugate us.

              """)
    trial3First()#calling the main stage of trial 3 
    

def trial3First():
    input("""
Press enter to continue...
    """)
    slowPrint("""
You are skeptical of Ron and Hermoine. What do you choose to do. 

A. Trust them and continue.
B. Jump out of the flying car.
C. Start screaming for help

    """)
    #each choice calls a related seperately defined function
    for tries in range(3):
        choice = (input("Choose you choice (A or B or C):  ")).lower()
        if choice == 'a':
            trial3Trust()
        elif choice == 'b':
            trial3Jump()
        elif choice == 'c':
            trial3Scream()
        else:
            if tries <2:
                print("Invalid Entry. Try again.")
            else:
                print("Choosing option B.")
                input("""
    
Press Enter to continue.
    
                """)
                trial3Jump()
                
                
    
    
def trial3Jump():   #Called in the Trial3First function at appropriate selection
    slowPrint("""
You jump out of the flying car and splatter all over the ground.
Architect: I mean, the laws of physics were implied, weren't they? Dumbass.

    """)
    input("""
    
Press Enter to continue.
    
    """)
    Failure()
def trial3Trust():#Called in the Trial3First function at appropriate selection
    input("""
    
Press Enter to continue.
    
    """)
    slowPrint(f"""
You guys arrive at the Oracle's home. The Oracle comes out hands you a cookie.
and takes examines your face closely. You're uncomfortable but intrigued.

Oracle: Being the chosen one is not a priviledge. It's a curse. Curse-ception, 
if you will *grins*

Oracle: To break out of the Matrix, you must, believe.

{player_name}: What does that even mean? 

Oracle: Yep, yep that's my b. Yeah so you just have to kill the architect. To 
complete this task, you will need these:

Acquired --> Elder Wand, the Resurrection Stone and the break function.

Use the Elder Wand to attack and weaken the Architect.
Use the Resurrection Stone to revive yourself (One time use only.)
Use the break function to break out of the matrix when the architect is 
immobilised.

Good luck, young grasshopper. 

You head to the Architect's lair.     
        """)
    
    input("""
    
Press Enter to continue.
    
    """)

    explosionTransition()

    slowPrint("""
The Architect appears and he is ANGRY. He uses his giant staff to laser beam
you out of existance. 

You jump out of the way in the final moment

What do you do?
    """)
    Numer_of_attacks = 0 #counting number of attacks to kill architect
    ResurrectionStoneLeft = 1 #used to once if killed by architect
    input("Prepare yourself. Think fast. Press enter to begin.")
    while True:
        
        for finaloption in range(3):
            
            slowPrint("""

    A. Attack using the Elder Wand
    B. Use the resurrection Stone
    C. Use the break function

            """)
            if(Numer_of_attacks >= 3):
                slowPrint("The Architect is weak. USE THE BREAK FUNCTION!")
            ArchitectChoice = (input("Choose A or B or C")).lower()
            if ArchitectChoice == 'a':
                Attack()
                Numer_of_attacks += 1
                break
            elif ArchitectChoice == 'b':
                if ResurrectionStoneLeft == 1:
                    slowPrint("There was no need for this, now you can't revive yourself")
                    ResurrectionStoneLeft-=1
                else:
                    slowPrint("You dont have a resurrection stone left.")
            elif ArchitectChoice == 'c':
                if (Numer_of_attacks < 2):
                    slowPrint("The Architect isn't weak enough. Attack using the elder wand first")
                else:
                    slowPrint("You broke out of the matrix")
                    success()
            else:
                if finaloption == 0 or finaloption == 1:
                    slowPrint("invalid entry. Try again.\n")
                elif finaloption == 2:
                    autoRespones =random.randint(0,5)
                    if autoRespones <=3:
                        Attack()
                        Numer_of_attacks += 1
                        break
                    elif autoRespones == 4:
                        if ResurrectionStoneLeft == 1:
                            print("You chose B. There was no need for this, now you can't revive yourself")
                            ResurrectionStoneLeft-=1
                        else:
                            print("You dont have a resurrection stone left.")
                    elif autoRespones == 5:
                        if (Numer_of_attacks < 2):
                            print("You chose C. The Architect isn't weak enough. Attack using the elder wand first")
                        else:
                            print("You broke out of the matrix")
                            success()
                else:
                    print("Code failed successfully. Let's all weep.")
        if ArchitectAttacks():
            if ResurrectionStoneLeft == 1:
                print("Using Resurrection Stone.")
                ResurrectionStoneLeft -= 1
            else:
                print("No Resurrection Stone Left. You are really dead.")
                Failure()
        


def ArchitectAttacks(): # function to randomly simulate the attacks of the architect
    attackChance = random.randint(0,5)
    if attackChance < 5:
        slowPrint("The architect tried to beam you. The attack missed.")
        return False
    if attackChance == 5:
        slowPrint("The Architect struck you. You died")
        return True
        

def Attack(): # function to simulate attack the architect
    slowPrint("""
    Expelliarmus! 
    
    You used the Elder wand to weaken the Architect.
    
    """)
    
def Resurrect(): #Function to simulate the use of the Resurrection stone
    slowPrint("you used the Resurrection Stone to revive yourself")
    
def breakoutOfProgram(): #Function to use the break power acquired in the trial3TRUST function
    slowPrint("""You used break!""")
    success()
    
def success():#Function to signify winning the game
    slowPrint(f"""
{'*'*60}
You have beaten the Architect and are free of the Curse of the Chase'ura.
Congratulations!
{'*'*60}
    """)
    sys.exit()
    
def trial3Scream(): #Called in the Trial3First function at appropriate selection
    input("\nYou have started to scream and cry. \n\nPress enter to continue\n\n")
    
    slowPrint(f"""
    
The Architect appears. Architect tries to to Laser Ron and Hermoine but
they disappear into thin air. The Architect uses telekenesis to land the car.

The Architect: Errr... Thanks? This was all totally planned and was a trial.
               You, errmm.. Win, I guess. THE CURSE HAS TOTALLY BEEN LIFTED.
               Good luck DANK LORD aka {player_name}
               
You are sucked into a portal. 
    
    """)
    input("Press enter to continue, sucker.")
    
    trial1()
def explosionTransition(): #Transition Sequence
    slowPrint("BOOOOM!!")
    time.sleep(1)
    slowPrint("...")
    time.sleep(1)
    slowPrint("...")
    time.sleep(1)
    slowPrint("...")
    time.sleep(1)
    slowPrint("CRASSSHHHHH")   

def transition(): #Another Transition Sequence
    slowPrint("\n*Walking*")
    time.sleep(1)
    slowPrint("\n...")
    time.sleep(1)
    slowPrint("\n*Walking*")
    time.sleep(1)
    slowPrint("\n...\n")
    time.sleep(1)
    slowPrint(f"{player_name}: Woaaah!\n\n")

def Failure(): #called everytime the player loses the game
    slowPrint(f"""
{'*'*60}
You have failed the trial and are not worthy of the Throne of 
Dankness.
{'*'*60}
    """)
    sys.exit()
    
    
introduction()#Calling the game to begin
# Out:
# Architect:
# Long ago, in a distan-
# Man! That is such a terrible way to tell a story.
# Not gonna lie though, Samurai Jack was pretty dope. Anyway, young coder,
# you're in for a treat! What are you in for you ask? Well, imagine a land
# without copyright issues or fourth walls. The look on your face
# suggests, either you're confused 🤣 or constipated or are here to
# break my code 😠
#
# Well, in that case, forget everything I said.
#
# You have been cursed by the evil lord Chase'ura to be forever banished
# in this realm of pop culture and everything, I the architect, cares for.
#
# I am sure you have a lot of questions but-
# ----------------------------------------
# So, oh naive one, do you remember your name?
#
#     I mean, yeah, I guess. I am hkhlnjvg
#
# That is correct, Hkhlnjvg. I'm glad your brain is still intact.
# So, I have good news and bad news. The good news is, I am about to have a lot of
# ...

# %%
a
